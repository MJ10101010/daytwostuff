# %% [markdown]
# _Connecting to Python 3.12.3..._

# %%
import pandas as pd
import numpy as np  
from sodapy import Socrata 
import folium
from folium import plugins

# %%
import pandas as pd

df = pd.read_csv('Depression.csv')
print(df.head())

# %%
import pandas as pd

df = pd.read_csv('Depression.csv')
df.head()
